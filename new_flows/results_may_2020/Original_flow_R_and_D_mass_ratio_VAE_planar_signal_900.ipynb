# %%
import numpy as np
import scipy as sp
import scipy.stats
import itertools
import logging
import matplotlib.pyplot as plt
import pandas as pd
import torch.utils.data as utils
import math
import time
import tqdm

import torch
import torch.optim as optim
import torch.nn.functional as F
from argparse import ArgumentParser
from torch.distributions import MultivariateNormal

import torch.nn as nn
import torch.nn.init as init

from flows import RealNVP
from models import NormalizingFlowModel

# %% [markdown]
# ## Load and process the data

# %%
f_PureBkg = pd.read_hdf("../../../2_lhc/LHC_Olympics2020/processing/test_dataset/MassRatio_RandD_signal_900.h5")
dt_PureBkg = f_PureBkg.values

# %%
dt_PureBkg[:,1] = (dt_PureBkg[:,1]-np.mean(dt_PureBkg[:,1]))/np.std(dt_PureBkg[:,1])
dt_PureBkg[:,2] = (dt_PureBkg[:,2]-np.mean(dt_PureBkg[:,2]))/np.std(dt_PureBkg[:,2])
dt_PureBkg[:,3] = (dt_PureBkg[:,3]-np.mean(dt_PureBkg[:,3]))/np.std(dt_PureBkg[:,3])
dt_PureBkg[:,4] = (dt_PureBkg[:,4]-np.mean(dt_PureBkg[:,4]))/np.std(dt_PureBkg[:,4])
dt_PureBkg[:,5] = (dt_PureBkg[:,5]-np.mean(dt_PureBkg[:,5]))/np.std(dt_PureBkg[:,5])
dt_PureBkg[:,6] = (dt_PureBkg[:,6]-np.mean(dt_PureBkg[:,6]))/np.std(dt_PureBkg[:,6])


dt_PureBkg[:,8] = (dt_PureBkg[:,8]-np.mean(dt_PureBkg[:,8]))/np.std(dt_PureBkg[:,8])
dt_PureBkg[:,9] = (dt_PureBkg[:,9]-np.mean(dt_PureBkg[:,9]))/np.std(dt_PureBkg[:,9])
dt_PureBkg[:,10] = (dt_PureBkg[:,10]-np.mean(dt_PureBkg[:,10]))/np.std(dt_PureBkg[:,10])
dt_PureBkg[:,11] = (dt_PureBkg[:,11]-np.mean(dt_PureBkg[:,11]))/np.std(dt_PureBkg[:,11])
dt_PureBkg[:,12] = (dt_PureBkg[:,12]-np.mean(dt_PureBkg[:,12]))/np.std(dt_PureBkg[:,12])

dt_PureBkg[:,14] = (dt_PureBkg[:,14]-np.mean(dt_PureBkg[:,14]))/np.std(dt_PureBkg[:,14])
dt_PureBkg[:,15] = (dt_PureBkg[:,15]-np.mean(dt_PureBkg[:,15]))/np.std(dt_PureBkg[:,15])
dt_PureBkg[:,16] = (dt_PureBkg[:,16]-np.mean(dt_PureBkg[:,16]))/np.std(dt_PureBkg[:,16])
dt_PureBkg[:,17] = (dt_PureBkg[:,17]-np.mean(dt_PureBkg[:,17]))/np.std(dt_PureBkg[:,17])
dt_PureBkg[:,18] = (dt_PureBkg[:,18]-np.mean(dt_PureBkg[:,18]))/np.std(dt_PureBkg[:,18])
dt_PureBkg[:,19] = (dt_PureBkg[:,19]-np.mean(dt_PureBkg[:,19]))/np.std(dt_PureBkg[:,19])


dt_PureBkg[:,21] = (dt_PureBkg[:,21]-np.mean(dt_PureBkg[:,21]))/np.std(dt_PureBkg[:,21])
dt_PureBkg[:,22] = (dt_PureBkg[:,22]-np.mean(dt_PureBkg[:,22]))/np.std(dt_PureBkg[:,22])
dt_PureBkg[:,23] = (dt_PureBkg[:,23]-np.mean(dt_PureBkg[:,23]))/np.std(dt_PureBkg[:,23])
dt_PureBkg[:,24] = (dt_PureBkg[:,24]-np.mean(dt_PureBkg[:,24]))/np.std(dt_PureBkg[:,24])
dt_PureBkg[:,25] = (dt_PureBkg[:,25]-np.mean(dt_PureBkg[:,25]))/np.std(dt_PureBkg[:,25])

# %%
total_PureBkg = torch.tensor(dt_PureBkg)
total_PureBkg_train_x_1 = total_PureBkg.t()[1:7].t()
total_PureBkg_train_x_2 = total_PureBkg.t()[8:13].t()
total_PureBkg_train_x_3 = total_PureBkg.t()[14:20].t()
total_PureBkg_train_x_4 = total_PureBkg.t()[21:26].t()

total_PureBkg_selection = torch.cat((total_PureBkg_train_x_1,total_PureBkg_train_x_2,total_PureBkg_train_x_3,total_PureBkg_train_x_4),dim=1)

# %%
bs = 1000
#bkgAE_dataset = utils.TensorDataset(data_train_x,data_train_x) 
bkgAE_train_iterator = utils.DataLoader(total_PureBkg_selection, batch_size=bs, shuffle=True) 
bkgAE_test_iterator = utils.DataLoader(total_PureBkg_selection, batch_size=bs)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
torch.cuda.get_device_name(0)
# Out:
# cuda:0
# 'Quadro M4000'

# %% [markdown]
# ## Build the model

# %%
class PlanarFlow(nn.Module):
    def __init__(self, D):
        super().__init__()
        self.D = D

    def forward(self, z, lamda):
        '''
        z - latents from prev layer
        lambda - Flow parameters (b, w, u)
        b - scalar
        w - vector
        u - vector
        '''
        b = lamda[:, :1]
        w, u = lamda[:, 1:].chunk(2, dim=1)

        # Forward
        # f(z) = z + u tanh(w^T z + b)
        transf = F.tanh(
            z.unsqueeze(1).bmm(w.unsqueeze(2))[:, 0] + b
        )
        f_z = z + u * transf

        # Inverse
        # psi_z = tanh' (w^T z + b) w
        psi_z = (1 - transf ** 2) * w
        log_abs_det_jacobian = torch.log(
            (1 + psi_z.unsqueeze(1).bmm(u.unsqueeze(2))).abs()
        )

        return f_z, log_abs_det_jacobian

# %%
class NormalizingFlow(nn.Module):
    def __init__(self, K, D):
        super().__init__()
        self.flows = nn.ModuleList([PlanarFlow(D) for i in range(K)])

    def forward(self, z_k, flow_params):
        # ladj -> log abs det jacobian
        sum_ladj = 0
        for i, flow in enumerate(self.flows):
            z_k, ladj_k = flow(z_k, flow_params[i])
            sum_ladj += ladj_k

        return z_k, sum_ladj

# %%
class VAE_NF(nn.Module):
    def __init__(self, K, D):
        super().__init__()
        self.dim = D
        self.K = K
        self.encoder = nn.Sequential(
            nn.Linear(22, 96),
            nn.LeakyReLU(True),
            nn.Linear(96, 48),
            nn.LeakyReLU(True),            
            nn.Linear(48, D * 2 + K * (D * 2 + 1))
        )

        self.decoder = nn.Sequential(
            nn.Linear(D, 48),
            nn.LeakyReLU(True),
            nn.Linear(48, 96),
            nn.LeakyReLU(True),
            nn.Linear(96, 22),
            nn.Sigmoid()
        )

        self.flows = NormalizingFlow(K, D)

    def forward(self, x):
        # Run Encoder and get NF params
        enc = self.encoder(x)
        mu = enc[:, :self.dim]
        log_var = enc[:, self.dim: self.dim * 2]
        flow_params = enc[:, 2 * self.dim:].chunk(self.K, dim=1)

        # Re-parametrize
        sigma = (log_var * .5).exp()
        z = mu + sigma * torch.randn_like(sigma)
        kl_div = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())

        # Construct more expressive posterior with NF
        z_k, sum_ladj = self.flows(z, flow_params)
        kl_div = kl_div / x.size(0) - sum_ladj.mean()  # mean over batch

        # Run Decoder
        x_prime = self.decoder(z_k)
        return x_prime, kl_div

# %% [markdown]
# ## Creating Instance¶

# %%
BATCH_SIZE = 1000
N_EPOCHS = 200
PRINT_INTERVAL = 2000
NUM_WORKERS = 4
LR = 1e-4
MODEL = 'VAE-NF'  # VAE-NF | VAE

N_FLOWS = 2
Z_DIM = 3

n_steps = 0

# %%
if MODEL == 'VAE-NF':
    model = VAE_NF(N_FLOWS, Z_DIM).cuda()
else:
    model = VAE(Z_DIM).cuda()

# %%
optimizer = optim.Adam(model.parameters(), lr=LR)

# %%
def train():
    global n_steps
    train_loss = []
    model.train()

    for batch_idx, x in enumerate(bkgAE_train_iterator):
        start_time = time.time()
        
        x = x.float().cuda()

        x_tilde, kl_div = model(x)
        loss_recons = F.binary_cross_entropy(x_tilde, x, size_average=False) / x.size(0)
        loss = loss_recons + kl_div

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss.append([loss_recons.item(), kl_div.item()])
        #writer.add_scalar('loss/train/ELBO', loss.item(), n_steps)
        #writer.add_scalar('loss/train/reconstruction', loss_recons.item(), n_steps)
        #writer.add_scalar('loss/train/KL', kl_div.item(), n_steps)

        if (batch_idx + 1) % PRINT_INTERVAL == 0:
            print('\tIter [{}/{} ({:.0f}%)]\tLoss: {} Time: {:5.3f} ms/batch'.format(
                batch_idx * len(x), 50000,
                PRINT_INTERVAL * batch_idx / 50000,
                np.asarray(train_loss)[-PRINT_INTERVAL:].mean(0),
                1000 * (time.time() - start_time)
            ))

        n_steps += 1

# %%
def evaluate(split='valid'):
    global n_steps
    start_time = time.time()
    val_loss = []
    model.eval()

    with torch.no_grad():
        for batch_idx, x in enumerate(bkgAE_test_iterator):
            
            x = x.float().cuda()

            x_tilde, kl_div = model(x)
            loss_recons = F.binary_cross_entropy(x_tilde, x, size_average=False) / x.size(0)
            loss = loss_recons + kl_div

            val_loss.append(loss.item())
            #writer.add_scalar('loss/{}/ELBO'.format(split), loss.item(), n_steps)
            #writer.add_scalar('loss/{}/reconstruction'.format(split), loss_recons.item(), n_steps)
            #writer.add_scalar('loss/{}/KL'.format(split), kl_div.item(), n_steps)

    print('\nEvaluation Completed ({})!\tLoss: {:5.4f} Time: {:5.3f} s'.format(
        split,
        np.asarray(val_loss).mean(0),
        time.time() - start_time
    ))
    return np.asarray(val_loss).mean(0)

# %%
BEST_LOSS = 99999
LAST_SAVED = -1
for epoch in range(1, N_EPOCHS):
    print("Epoch {}:".format(epoch))
    train()
    cur_loss = evaluate()

    if cur_loss <= BEST_LOSS:
        BEST_LOSS = cur_loss
        LAST_SAVED = epoch
        print("Saving model!")
        torch.save(model.state_dict(), "lhc_weights/original_signal_900_vae_NF_planar.h5")
    else:
        print("Not saving model! Last saved: {}".format(LAST_SAVED))
# Out:
# Epoch 1:
#
# Evaluation Completed (valid)!	Loss: -302.2750 Time: 0.424 s
# Saving model!
# Epoch 2:
#
# Evaluation Completed (valid)!	Loss: -303.9700 Time: 0.485 s
# Saving model!
# Epoch 3:
#
# Evaluation Completed (valid)!	Loss: -302.4605 Time: 0.427 s
# Not saving model! Last saved: 2
# Epoch 4:
#
# Evaluation Completed (valid)!	Loss: -301.7926 Time: 0.482 s
# Not saving model! Last saved: 2
# Epoch 5:
#
# Evaluation Completed (valid)!	Loss: -302.6695 Time: 0.515 s
# Not saving model! Last saved: 2
# Epoch 6:
#
# Evaluation Completed (valid)!	Loss: -302.6581 Time: 0.499 s
# Not saving model! Last saved: 2
# Epoch 7:
#
# Evaluation Completed (valid)!	Loss: -302.0356 Time: 0.566 s
# Not saving model! Last saved: 2
# Epoch 8:
#
# Evaluation Completed (valid)!	Loss: -302.0821 Time: 0.514 s
# Not saving model! Last saved: 2
# Epoch 9:
#
# Evaluation Completed (valid)!	Loss: -302.0331 Time: 0.487 s
# Not saving model! Last saved: 2
# Epoch 10:
#
# Evaluation Completed (valid)!	Loss: -302.5338 Time: 0.522 s
# Not saving model! Last saved: 2
# Epoch 11:
#
# Evaluation Completed (valid)!	Loss: -302.6587 Time: 0.551 s
# Not saving model! Last saved: 2
# Epoch 12:
#
# Evaluation Completed (valid)!	Loss: -303.9380 Time: 0.581 s
# Not saving model! Last saved: 2
# Epoch 13:
#
# Evaluation Completed (valid)!	Loss: -298.8568 Time: 0.542 s
# Not saving model! Last saved: 2
# Epoch 14:
#
# Evaluation Completed (valid)!	Loss: -309.3319 Time: 0.630 s
# Saving model!
# Epoch 15:
#
# Evaluation Completed (valid)!	Loss: -307.2505 Time: 0.426 s
# Not saving model! Last saved: 14
# Epoch 16:
#
# Evaluation Completed (valid)!	Loss: -307.6225 Time: 0.545 s
# Not saving model! Last saved: 14
# Epoch 17:
#
# Evaluation Completed (valid)!	Loss: -308.2538 Time: 0.559 s
# Not saving model! Last saved: 14
# Epoch 18:
#
# Evaluation Completed (valid)!	Loss: -309.1246 Time: 0.481 s
# Not saving model! Last saved: 14
# Epoch 19:
#
# Evaluation Completed (valid)!	Loss: -308.5078 Time: 0.483 s
# Not saving model! Last saved: 14
# Epoch 20:
#
# Evaluation Completed (valid)!	Loss: -309.0116 Time: 0.531 s
# Not saving model! Last saved: 14
# Epoch 21:
#
# Evaluation Completed (valid)!	Loss: -308.3363 Time: 0.529 s
# Not saving model! Last saved: 14
# Epoch 22:
#
# Evaluation Completed (valid)!	Loss: -308.1678 Time: 0.566 s
# Not saving model! Last saved: 14
# Epoch 23:
#
# Evaluation Completed (valid)!	Loss: -305.8295 Time: 0.576 s
# Not saving model! Last saved: 14
# Epoch 24:
#
# Evaluation Completed (valid)!	Loss: -303.6621 Time: 0.587 s
# Not saving model! Last saved: 14
# Epoch 25:
#
# Evaluation Completed (valid)!	Loss: -305.8120 Time: 0.574 s
# Not saving model! Last saved: 14
# Epoch 26:
#
# Evaluation Completed (valid)!	Loss: -305.6058 Time: 0.586 s
# Not saving model! Last saved: 14
# Epoch 27:
#
# Evaluation Completed (valid)!	Loss: -304.7749 Time: 0.566 s
# Not saving model! Last saved: 14
# Epoch 28:
#
# Evaluation Completed (valid)!	Loss: -304.6504 Time: 0.526 s
# Not saving model! Last saved: 14
# Epoch 29:
#
# Evaluation Completed (valid)!	Loss: -305.7181 Time: 0.516 s
# Not saving model! Last saved: 14
# Epoch 30:
#
# Evaluation Completed (valid)!	Loss: -306.8745 Time: 0.534 s
# Not saving model! Last saved: 14
# Epoch 31:
#
# Evaluation Completed (valid)!	Loss: -307.4757 Time: 0.535 s
# Not saving model! Last saved: 14
# Epoch 32:
#
# Evaluation Completed (valid)!	Loss: -307.4283 Time: 0.491 s
# Not saving model! Last saved: 14
# Epoch 33:
#
# Evaluation Completed (valid)!	Loss: -307.6792 Time: 0.535 s
# Not saving model! Last saved: 14
# Epoch 34:
#
# Evaluation Completed (valid)!	Loss: -306.8525 Time: 0.635 s
# Not saving model! Last saved: 14
# Epoch 35:
#
# Evaluation Completed (valid)!	Loss: -306.5820 Time: 0.577 s
# Not saving model! Last saved: 14
# Epoch 36:
#
# Evaluation Completed (valid)!	Loss: -306.4643 Time: 0.577 s
# Not saving model! Last saved: 14
# Epoch 37:
#
# Evaluation Completed (valid)!	Loss: -306.6972 Time: 0.706 s
# Not saving model! Last saved: 14
# Epoch 38:
#
# Evaluation Completed (valid)!	Loss: -306.6841 Time: 0.536 s
# Not saving model! Last saved: 14
# Epoch 39:
#
# Evaluation Completed (valid)!	Loss: -308.2503 Time: 0.529 s
# Not saving model! Last saved: 14
# Epoch 40:
#
# Evaluation Completed (valid)!	Loss: -306.8629 Time: 0.503 s
# Not saving model! Last saved: 14
# Epoch 41:
#
# Evaluation Completed (valid)!	Loss: -306.8099 Time: 0.501 s
# Not saving model! Last saved: 14
# Epoch 42:
#
# Evaluation Completed (valid)!	Loss: -306.5177 Time: 0.528 s
# Not saving model! Last saved: 14
# Epoch 43:
#
# Evaluation Completed (valid)!	Loss: -306.5616 Time: 0.546 s
# Not saving model! Last saved: 14
# Epoch 44:
#
# Evaluation Completed (valid)!	Loss: -306.4213 Time: 0.596 s
# Not saving model! Last saved: 14
# Epoch 45:
#
# Evaluation Completed (valid)!	Loss: -306.9726 Time: 0.582 s
# Not saving model! Last saved: 14
# Epoch 46:
#
# Evaluation Completed (valid)!	Loss: -307.5945 Time: 0.579 s
# Not saving model! Last saved: 14
# Epoch 47:
#
# Evaluation Completed (valid)!	Loss: -306.2685 Time: 0.587 s
# Not saving model! Last saved: 14
# Epoch 48:
#
# Evaluation Completed (valid)!	Loss: -305.6729 Time: 0.525 s
# Not saving model! Last saved: 14
# Epoch 49:
#
# Evaluation Completed (valid)!	Loss: -306.1481 Time: 0.492 s
# Not saving model! Last saved: 14
# Epoch 50:
#
# Evaluation Completed (valid)!	Loss: -305.4989 Time: 0.526 s
# Not saving model! Last saved: 14
# Epoch 51:
#
# Evaluation Completed (valid)!	Loss: -306.1304 Time: 0.526 s
# Not saving model! Last saved: 14
# Epoch 52:
#
# Evaluation Completed (valid)!	Loss: -305.4977 Time: 0.523 s
# Not saving model! Last saved: 14
# Epoch 53:
#
# Evaluation Completed (valid)!	Loss: -305.5356 Time: 0.527 s
# Not saving model! Last saved: 14
# Epoch 54:
#
# Evaluation Completed (valid)!	Loss: -305.7743 Time: 0.588 s
# Not saving model! Last saved: 14
# Epoch 55:
#
# Evaluation Completed (valid)!	Loss: -304.9184 Time: 0.527 s
# Not saving model! Last saved: 14
# Epoch 56:
#
# Evaluation Completed (valid)!	Loss: -305.6229 Time: 0.545 s
# Not saving model! Last saved: 14
# Epoch 57:
#
# Evaluation Completed (valid)!	Loss: -305.8817 Time: 0.553 s
# Not saving model! Last saved: 14
# Epoch 58:
#
# Evaluation Completed (valid)!	Loss: -305.2620 Time: 0.504 s
# Not saving model! Last saved: 14
# Epoch 59:
#
# Evaluation Completed (valid)!	Loss: -305.4250 Time: 0.531 s
# Not saving model! Last saved: 14
# Epoch 60:
#
# Evaluation Completed (valid)!	Loss: -304.8326 Time: 0.485 s
# Not saving model! Last saved: 14
# Epoch 61:
#
# Evaluation Completed (valid)!	Loss: -306.6566 Time: 0.529 s
# Not saving model! Last saved: 14
# Epoch 62:
#
# Evaluation Completed (valid)!	Loss: -307.3157 Time: 0.487 s
# Not saving model! Last saved: 14
# Epoch 63:
#
# Evaluation Completed (valid)!	Loss: -306.2869 Time: 0.534 s
# Not saving model! Last saved: 14
# Epoch 64:
#
# Evaluation Completed (valid)!	Loss: -305.2529 Time: 0.550 s
# Not saving model! Last saved: 14
# Epoch 65:
#
# Evaluation Completed (valid)!	Loss: -304.9375 Time: 0.534 s
# Not saving model! Last saved: 14
# Epoch 66:
#
# Evaluation Completed (valid)!	Loss: -305.0425 Time: 0.561 s
# Not saving model! Last saved: 14
# Epoch 67:
#
# Evaluation Completed (valid)!	Loss: -306.0535 Time: 0.563 s
# Not saving model! Last saved: 14
# Epoch 68:
#
# Evaluation Completed (valid)!	Loss: -305.0752 Time: 0.576 s
# Not saving model! Last saved: 14
# Epoch 69:
#
# Evaluation Completed (valid)!	Loss: -304.2757 Time: 0.557 s
# Not saving model! Last saved: 14
# Epoch 70:
#
# Evaluation Completed (valid)!	Loss: -305.2894 Time: 0.505 s
# Not saving model! Last saved: 14
# Epoch 71:
#
# Evaluation Completed (valid)!	Loss: -305.1540 Time: 0.527 s
# Not saving model! Last saved: 14
# Epoch 72:
#
# Evaluation Completed (valid)!	Loss: -303.1528 Time: 0.499 s
# Not saving model! Last saved: 14
# Epoch 73:
#
# Evaluation Completed (valid)!	Loss: -304.2609 Time: 0.528 s
# Not saving model! Last saved: 14
# Epoch 74:
#
# Evaluation Completed (valid)!	Loss: -304.1688 Time: 0.566 s
# Not saving model! Last saved: 14
# Epoch 75:
#
# Evaluation Completed (valid)!	Loss: -303.6515 Time: 0.566 s
# Not saving model! Last saved: 14
# Epoch 76:
#
# Evaluation Completed (valid)!	Loss: -304.1473 Time: 0.494 s
# Not saving model! Last saved: 14
# Epoch 77:
#
# Evaluation Completed (valid)!	Loss: -304.2720 Time: 0.559 s
# Not saving model! Last saved: 14
# Epoch 78:
#
# Evaluation Completed (valid)!	Loss: -304.7712 Time: 0.563 s
# Not saving model! Last saved: 14
# Epoch 79:
#
# Evaluation Completed (valid)!	Loss: -304.6187 Time: 0.576 s
# Not saving model! Last saved: 14
# Epoch 80:
#
# Evaluation Completed (valid)!	Loss: -304.7031 Time: 0.459 s
# Not saving model! Last saved: 14
# Epoch 81:
# Evaluation Completed (valid)!	Loss: -305.6100 Time: 0.627 s
# Not saving model! Last saved: 14
# Epoch 82:
#
# Evaluation Completed (valid)!	Loss: -304.6694 Time: 0.534 s
# Not saving model! Last saved: 14
# Epoch 83:
#
# Evaluation Completed (valid)!	Loss: -305.7115 Time: 0.564 s
# Not saving model! Last saved: 14
# Epoch 84:
#
# Evaluation Completed (valid)!	Loss: -305.1605 Time: 0.591 s
# Not saving model! Last saved: 14
# Epoch 85:
#
# Evaluation Completed (valid)!	Loss: -305.2272 Time: 0.534 s
# Not saving model! Last saved: 14
# Epoch 86:
#
# Evaluation Completed (valid)!	Loss: -304.6697 Time: 0.488 s
# Not saving model! Last saved: 14
# Epoch 87:
#
# Evaluation Completed (valid)!	Loss: -305.2375 Time: 0.530 s
# Not saving model! Last saved: 14
# Epoch 88:
#
# Evaluation Completed (valid)!	Loss: -304.9008 Time: 0.498 s
# Not saving model! Last saved: 14
# Epoch 89:
#
# Evaluation Completed (valid)!	Loss: -304.6319 Time: 0.578 s
# Not saving model! Last saved: 14
# Epoch 90:
#
# Evaluation Completed (valid)!	Loss: -305.2092 Time: 0.580 s
# Not saving model! Last saved: 14
# Epoch 91:
#
# Evaluation Completed (valid)!	Loss: -304.4987 Time: 0.594 s
# Not saving model! Last saved: 14
# Epoch 92:
#
# Evaluation Completed (valid)!	Loss: -305.3255 Time: 0.590 s
# Not saving model! Last saved: 14
# Epoch 93:
#
# Evaluation Completed (valid)!	Loss: -305.4961 Time: 0.528 s
# Not saving model! Last saved: 14
# Epoch 94:
#
# Evaluation Completed (valid)!	Loss: -296.9098 Time: 0.587 s
# Not saving model! Last saved: 14
# Epoch 95:
#
# Evaluation Completed (valid)!	Loss: -309.2288 Time: 0.540 s
# Not saving model! Last saved: 14
# Epoch 96:
#
# Evaluation Completed (valid)!	Loss: -310.0062 Time: 0.532 s
# Saving model!
# Epoch 97:
#
# Evaluation Completed (valid)!	Loss: -309.7457 Time: 0.496 s
# Not saving model! Last saved: 96
# Epoch 98:
#
# Evaluation Completed (valid)!	Loss: -309.4513 Time: 0.552 s
# Not saving model! Last saved: 96
# Epoch 99:
#
# Evaluation Completed (valid)!	Loss: -310.3575 Time: 0.536 s
# Saving model!
# Epoch 100:
#
# Evaluation Completed (valid)!	Loss: -310.4807 Time: 0.551 s
# Saving model!
# Epoch 101:
#
# Evaluation Completed (valid)!	Loss: -310.7162 Time: 0.567 s
# Saving model!
# Epoch 102:
#
# Evaluation Completed (valid)!	Loss: -310.8091 Time: 0.575 s
# Saving model!
# Epoch 103:
#
# Evaluation Completed (valid)!	Loss: -310.7503 Time: 0.591 s
# Not saving model! Last saved: 102
# Epoch 104:
#
# Evaluation Completed (valid)!	Loss: -307.0028 Time: 0.569 s
# Not saving model! Last saved: 102
# Epoch 105:
#
# Evaluation Completed (valid)!	Loss: -309.7889 Time: 0.493 s
# Not saving model! Last saved: 102
# Epoch 106:
#
# Evaluation Completed (valid)!	Loss: -308.5686 Time: 0.526 s
# Not saving model! Last saved: 102
# Epoch 107:
#
# Evaluation Completed (valid)!	Loss: -310.8044 Time: 0.567 s
# Not saving model! Last saved: 102
# Epoch 108:
#
# Evaluation Completed (valid)!	Loss: -311.0660 Time: 0.528 s
# Saving model!
# Epoch 109:
#
# Evaluation Completed (valid)!	Loss: -310.3903 Time: 0.531 s
# Not saving model! Last saved: 108
# Epoch 110:
#
# Evaluation Completed (valid)!	Loss: -311.6251 Time: 0.529 s
# Saving model!
# Epoch 111:
#
# Evaluation Completed (valid)!	Loss: -311.4239 Time: 0.533 s
# Not saving model! Last saved: 110
# Epoch 112:
#
# Evaluation Completed (valid)!	Loss: -311.5871 Time: 0.585 s
# Not saving model! Last saved: 110
# Epoch 113:
#
# Evaluation Completed (valid)!	Loss: -311.7726 Time: 0.522 s
# Saving model!
# Epoch 114:
#
# Evaluation Completed (valid)!	Loss: -310.0884 Time: 0.704 s
# Not saving model! Last saved: 113
# Epoch 115:
#
# Evaluation Completed (valid)!	Loss: -310.8859 Time: 0.543 s
# Not saving model! Last saved: 113
# Epoch 116:
#
# Evaluation Completed (valid)!	Loss: -311.1860 Time: 0.527 s
# Not saving model! Last saved: 113
# Epoch 117:
#
# Evaluation Completed (valid)!	Loss: -311.2539 Time: 0.517 s
# Not saving model! Last saved: 113
# Epoch 118:
#
# Evaluation Completed (valid)!	Loss: -311.0240 Time: 0.495 s
# Not saving model! Last saved: 113
# Epoch 119:
#
# Evaluation Completed (valid)!	Loss: -310.0626 Time: 0.540 s
# Not saving model! Last saved: 113
# Epoch 120:
#
# Evaluation Completed (valid)!	Loss: -310.2370 Time: 0.525 s
# Not saving model! Last saved: 113
# Epoch 121:
#
# Evaluation Completed (valid)!	Loss: -310.3492 Time: 0.508 s
# Not saving model! Last saved: 113
# Epoch 122:
#
# Evaluation Completed (valid)!	Loss: -310.1846 Time: 0.520 s
# Not saving model! Last saved: 113
# Epoch 123:
#
# Evaluation Completed (valid)!	Loss: -308.4889 Time: 0.580 s
# Not saving model! Last saved: 113
# Epoch 124:
#
# Evaluation Completed (valid)!	Loss: -307.7254 Time: 0.618 s
# Not saving model! Last saved: 113
# Epoch 125:
#
# Evaluation Completed (valid)!	Loss: -308.9987 Time: 0.510 s
# Not saving model! Last saved: 113
# Epoch 126:
#
# Evaluation Completed (valid)!	Loss: -308.1704 Time: 0.518 s
# Not saving model! Last saved: 113
# Epoch 127:
#
# Evaluation Completed (valid)!	Loss: -308.4417 Time: 0.561 s
# Not saving model! Last saved: 113
# Epoch 128:
#
# Evaluation Completed (valid)!	Loss: -307.2422 Time: 0.527 s
# Not saving model! Last saved: 113
# Epoch 129:
#
# Evaluation Completed (valid)!	Loss: -308.2818 Time: 0.507 s
# Not saving model! Last saved: 113
# Epoch 130:
#
# Evaluation Completed (valid)!	Loss: -306.5074 Time: 0.564 s
# Not saving model! Last saved: 113
# Epoch 131:
#
# Evaluation Completed (valid)!	Loss: -307.5098 Time: 0.497 s
# Not saving model! Last saved: 113
# Epoch 132:
#
# Evaluation Completed (valid)!	Loss: -307.5884 Time: 0.529 s
# Not saving model! Last saved: 113
# Epoch 133:
#
# Evaluation Completed (valid)!	Loss: -311.0776 Time: 0.568 s
# Not saving model! Last saved: 113
# Epoch 134:
#
# Evaluation Completed (valid)!	Loss: -307.7748 Time: 0.639 s
# Not saving model! Last saved: 113
# Epoch 135:
#
# Evaluation Completed (valid)!	Loss: -307.8807 Time: 0.564 s
# Not saving model! Last saved: 113
# Epoch 136:
#
# Evaluation Completed (valid)!	Loss: -307.8691 Time: 0.533 s
# Not saving model! Last saved: 113
# Epoch 137:
#
# Evaluation Completed (valid)!	Loss: -310.5752 Time: 0.496 s
# Not saving model! Last saved: 113
# Epoch 138:
#
# Evaluation Completed (valid)!	Loss: -308.3385 Time: 0.503 s
# Not saving model! Last saved: 113
# Epoch 139:
#
# Evaluation Completed (valid)!	Loss: -309.3771 Time: 0.531 s
# Not saving model! Last saved: 113
# Epoch 140:
#
# Evaluation Completed (valid)!	Loss: -308.4762 Time: 0.490 s
# Not saving model! Last saved: 113
# Epoch 141:
#
# Evaluation Completed (valid)!	Loss: -307.8178 Time: 0.552 s
# Not saving model! Last saved: 113
# Epoch 142:
#
# Evaluation Completed (valid)!	Loss: -308.6388 Time: 0.524 s
# Not saving model! Last saved: 113
# Epoch 143:
#
# Evaluation Completed (valid)!	Loss: -308.5117 Time: 0.523 s
# Not saving model! Last saved: 113
# Epoch 144:
#
# Evaluation Completed (valid)!	Loss: -308.3457 Time: 0.613 s
# Not saving model! Last saved: 113
# Epoch 145:
#
# Evaluation Completed (valid)!	Loss: -307.0361 Time: 0.561 s
# Not saving model! Last saved: 113
# Epoch 146:
#
# Evaluation Completed (valid)!	Loss: -308.8269 Time: 0.573 s
# Not saving model! Last saved: 113
# Epoch 147:
#
# Evaluation Completed (valid)!	Loss: -307.0966 Time: 0.555 s
# Not saving model! Last saved: 113
# Epoch 148:
#
# Evaluation Completed (valid)!	Loss: -306.8171 Time: 0.534 s
# Not saving model! Last saved: 113
# Epoch 149:
#
# Evaluation Completed (valid)!	Loss: -306.2167 Time: 0.555 s
# Not saving model! Last saved: 113
# Epoch 150:
#
# Evaluation Completed (valid)!	Loss: -307.3230 Time: 0.491 s
# Not saving model! Last saved: 113
# Epoch 151:
#
# Evaluation Completed (valid)!	Loss: -308.2526 Time: 0.560 s
# Not saving model! Last saved: 113
# Epoch 152:
#
# Evaluation Completed (valid)!	Loss: -307.7900 Time: 0.487 s
# Not saving model! Last saved: 113
# Epoch 153:
#
# Evaluation Completed (valid)!	Loss: -308.5674 Time: 0.486 s
# Not saving model! Last saved: 113
# Epoch 154:
#
# Evaluation Completed (valid)!	Loss: -308.3418 Time: 0.567 s
# Not saving model! Last saved: 113
# Epoch 155:
#
# Evaluation Completed (valid)!	Loss: -308.5413 Time: 0.549 s
# Not saving model! Last saved: 113
# Epoch 156:
#
# Evaluation Completed (valid)!	Loss: -305.0732 Time: 0.561 s
# Not saving model! Last saved: 113
# Epoch 157:
#
# Evaluation Completed (valid)!	Loss: -308.8756 Time: 0.552 s
# Not saving model! Last saved: 113
# Epoch 158:
#
# Evaluation Completed (valid)!	Loss: -309.2553 Time: 0.556 s
# Not saving model! Last saved: 113
# Epoch 159:
#
# Evaluation Completed (valid)!	Loss: -308.4187 Time: 0.508 s
# Not saving model! Last saved: 113
# Epoch 160:
#
# Evaluation Completed (valid)!	Loss: -309.2772 Time: 0.536 s
# Not saving model! Last saved: 113
# Epoch 161:
# Evaluation Completed (valid)!	Loss: -309.4308 Time: 0.618 s
# Not saving model! Last saved: 113
# Epoch 162:
#
# Evaluation Completed (valid)!	Loss: -309.2864 Time: 0.526 s
# Not saving model! Last saved: 113
# Epoch 163:
#
# Evaluation Completed (valid)!	Loss: -309.6249 Time: 0.536 s
# Not saving model! Last saved: 113
# Epoch 164:
#
# Evaluation Completed (valid)!	Loss: -309.3034 Time: 0.574 s
# Not saving model! Last saved: 113
# Epoch 165:
#
# Evaluation Completed (valid)!	Loss: -309.2537 Time: 0.489 s
# Not saving model! Last saved: 113
# Epoch 166:
#
# Evaluation Completed (valid)!	Loss: -309.6870 Time: 0.500 s
# Not saving model! Last saved: 113
# Epoch 167:
#
# Evaluation Completed (valid)!	Loss: -309.5800 Time: 0.591 s
# Not saving model! Last saved: 113
# Epoch 168:
#
# Evaluation Completed (valid)!	Loss: -309.9396 Time: 0.581 s
# Not saving model! Last saved: 113
# Epoch 169:
#
# Evaluation Completed (valid)!	Loss: -310.6521 Time: 0.581 s
# Not saving model! Last saved: 113
# Epoch 170:
#
# Evaluation Completed (valid)!	Loss: -311.5250 Time: 0.514 s
# Not saving model! Last saved: 113
# Epoch 171:
#
# Evaluation Completed (valid)!	Loss: -310.6627 Time: 0.542 s
# Not saving model! Last saved: 113
# Epoch 172:
#
# Evaluation Completed (valid)!	Loss: -311.7268 Time: 0.537 s
# Not saving model! Last saved: 113
# Epoch 173:
#
# Evaluation Completed (valid)!	Loss: -313.6181 Time: 0.511 s
# Saving model!
# Epoch 174:
#
# Evaluation Completed (valid)!	Loss: -310.8339 Time: 0.591 s
# Not saving model! Last saved: 173
# Epoch 175:
#
# Evaluation Completed (valid)!	Loss: -307.6667 Time: 0.523 s
# Not saving model! Last saved: 173
# Epoch 176:
#
# Evaluation Completed (valid)!	Loss: -309.1629 Time: 0.518 s
# Not saving model! Last saved: 173
# Epoch 177:
#
# Evaluation Completed (valid)!	Loss: -309.8347 Time: 0.532 s
# Not saving model! Last saved: 173
# Epoch 178:
#
# Evaluation Completed (valid)!	Loss: -309.8712 Time: 0.581 s
# Not saving model! Last saved: 173
# Epoch 179:
#
# Evaluation Completed (valid)!	Loss: -312.7608 Time: 0.584 s
# Not saving model! Last saved: 173
# Epoch 180:
#
# Evaluation Completed (valid)!	Loss: -311.0438 Time: 0.583 s
# Not saving model! Last saved: 173
# Epoch 181:
#
# Evaluation Completed (valid)!	Loss: -310.8072 Time: 0.588 s
# Not saving model! Last saved: 173
# Epoch 182:
#
# Evaluation Completed (valid)!	Loss: -310.4603 Time: 0.519 s
# Not saving model! Last saved: 173
# Epoch 183:
#
# Evaluation Completed (valid)!	Loss: -313.7484 Time: 0.488 s
# Saving model!
# Epoch 184:
#
# Evaluation Completed (valid)!	Loss: -312.7223 Time: 0.574 s
# Not saving model! Last saved: 183
# Epoch 185:
#
# Evaluation Completed (valid)!	Loss: -314.9607 Time: 0.519 s
# Saving model!
# Epoch 186:
#
# Evaluation Completed (valid)!	Loss: -310.1250 Time: 0.492 s
# Not saving model! Last saved: 185
# Epoch 187:
#
# Evaluation Completed (valid)!	Loss: -309.7762 Time: 0.566 s
# Not saving model! Last saved: 185
# Epoch 188:
#
# Evaluation Completed (valid)!	Loss: -310.3710 Time: 0.494 s
# Not saving model! Last saved: 185
# Epoch 189:
#
# Evaluation Completed (valid)!	Loss: -310.9318 Time: 0.536 s
# Not saving model! Last saved: 185
# Epoch 190:
#
# Evaluation Completed (valid)!	Loss: -310.8911 Time: 0.567 s
# Not saving model! Last saved: 185
# Epoch 191:
#
# Evaluation Completed (valid)!	Loss: -307.2692 Time: 0.610 s
# Not saving model! Last saved: 185
# Epoch 192:
#
# Evaluation Completed (valid)!	Loss: -307.1921 Time: 0.478 s
# Not saving model! Last saved: 185
# Epoch 193:
#
# Evaluation Completed (valid)!	Loss: -307.5545 Time: 0.520 s
# Not saving model! Last saved: 185
# Epoch 194:
#
# Evaluation Completed (valid)!	Loss: -308.5332 Time: 0.588 s
# Not saving model! Last saved: 185
# Epoch 195:
#
# Evaluation Completed (valid)!	Loss: -309.8101 Time: 0.496 s
# Not saving model! Last saved: 185
# Epoch 196:
#
# Evaluation Completed (valid)!	Loss: -309.4160 Time: 0.544 s
# Not saving model! Last saved: 185
# Epoch 197:
#
# Evaluation Completed (valid)!	Loss: -312.2699 Time: 0.488 s
# Not saving model! Last saved: 185
# Epoch 198:
#
# Evaluation Completed (valid)!	Loss: -311.7382 Time: 0.550 s
# Not saving model! Last saved: 185
# Epoch 199:
#
# Evaluation Completed (valid)!	Loss: -311.4446 Time: 0.505 s
# Not saving model! Last saved: 185

# %% [markdown]
# ## Testing with the trained model

# %%
def get_mass_and_loss(inputstring):
    f_in = pd.read_hdf(inputstring)
    dt_in = f_in.values
    dt_in[:,1] = (dt_in[:,1]-np.mean(dt_in[:,1]))/np.std(dt_in[:,1])
    dt_in[:,2] = (dt_in[:,2]-np.mean(dt_in[:,2]))/np.std(dt_in[:,2])
    dt_in[:,3] = (dt_in[:,3]-np.mean(dt_in[:,3]))/np.std(dt_in[:,3])
    dt_in[:,4] = (dt_in[:,4]-np.mean(dt_in[:,4]))/np.std(dt_in[:,4])
    dt_in[:,5] = (dt_in[:,5]-np.mean(dt_in[:,5]))/np.std(dt_in[:,5])
    dt_in[:,6] = (dt_in[:,6]-np.mean(dt_in[:,6]))/np.std(dt_in[:,6])

    dt_in[:,8] = (dt_in[:,8]-np.mean(dt_in[:,8]))/np.std(dt_in[:,8])
    dt_in[:,9] = (dt_in[:,9]-np.mean(dt_in[:,9]))/np.std(dt_in[:,9])
    dt_in[:,10] = (dt_in[:,10]-np.mean(dt_in[:,10]))/np.std(dt_in[:,10])
    dt_in[:,11] = (dt_in[:,11]-np.mean(dt_in[:,11]))/np.std(dt_in[:,11])
    dt_in[:,12] = (dt_in[:,12]-np.mean(dt_in[:,12]))/np.std(dt_in[:,12])

    dt_in[:,14] = (dt_in[:,14]-np.mean(dt_in[:,14]))/np.std(dt_in[:,14])
    dt_in[:,15] = (dt_in[:,15]-np.mean(dt_in[:,15]))/np.std(dt_in[:,15])
    dt_in[:,16] = (dt_in[:,16]-np.mean(dt_in[:,16]))/np.std(dt_in[:,16])
    dt_in[:,17] = (dt_in[:,17]-np.mean(dt_in[:,17]))/np.std(dt_in[:,17])
    dt_in[:,18] = (dt_in[:,18]-np.mean(dt_in[:,18]))/np.std(dt_in[:,18])
    dt_in[:,19] = (dt_in[:,19]-np.mean(dt_in[:,19]))/np.std(dt_in[:,19])
    
    dt_in[:,21] = (dt_in[:,21]-np.mean(dt_in[:,21]))/np.std(dt_in[:,21])
    dt_in[:,22] = (dt_in[:,22]-np.mean(dt_in[:,22]))/np.std(dt_in[:,22])
    dt_in[:,23] = (dt_in[:,23]-np.mean(dt_in[:,23]))/np.std(dt_in[:,23])
    dt_in[:,24] = (dt_in[:,24]-np.mean(dt_in[:,24]))/np.std(dt_in[:,24])
    dt_in[:,25] = (dt_in[:,25]-np.mean(dt_in[:,25]))/np.std(dt_in[:,25])


    
    
    total_in = torch.tensor(dt_in)
    total_in_train_x_1 = total_in.t()[1:7].t()
    total_in_train_x_2 = total_in.t()[8:13].t()
    total_in_train_x_3 = total_in.t()[14:20].t()
    total_in_train_x_4 = total_in.t()[21:26].t()
    total_in_selection = torch.cat((total_in_train_x_1,total_in_train_x_2,total_in_train_x_3,total_in_train_x_4),dim=1)
    
    loss_total_in = torch.mean((model(total_in_selection.float().cuda())[0]-
                       total_in_selection.float().cuda())**2,dim=1).data.cpu().numpy()
    
    f_in = pd.read_hdf(inputstring)
    dt_in = f_in.values
    
    return dt_in[:,0], dt_in[:,10], dt_in[:,23], dt_in[:,9], dt_in[:,22], loss_total_in

# %%
def get_mass(inputstring):

    f_in = pd.read_hdf(inputstring)
    dt_in = f_in.values
    
    return dt_in[:,0]

# %%
bb2mass = get_mass("../../../2_lhc/LHC_Olympics2020/processing/test_dataset/MassRatio_BB1.h5")
purebkgmass = get_mass("../../../2_lhc/LHC_Olympics2020/processing/test_dataset/MassRatio_pureBkg.h5")

# %%
bb2mass, bb2mmdt1, bb2mmdt2, bb2prun1,bb2prun2, bb2loss = get_mass_and_loss("../../../2_lhc/LHC_Olympics2020/processing/test_dataset/MassRatio_BB1.h5")
purebkgmass, purebkgmmdt1, purebkgmmdt2, purebkgprun1,purebkgprun2, purebkgloss = get_mass_and_loss("../../../2_lhc/LHC_Olympics2020/processing/test_dataset/MassRatio_pureBkg.h5")

# %%
plt.rcParams["figure.figsize"] = (10,10)
bins = np.linspace(0,5,1100)
#plt.hist(purebkgloss[np.where((purebkgmass>6000) & (purebkgmass<7000))[0]],bins=bins,label='background',color="blue");
#plt.hist(bb2loss[np.where((bb2mass>6000) & (bb2mass<7000))[0]],bins=bins,label='Blackbox2',histtype='step',color="red");
#plt.semilogy()
plt.hist(bb2loss,bins=bins,alpha=0.3,color='b',label='blackbox1')
plt.hist(purebkgloss,bins=bins,alpha=0.3,color='r',label='background')
plt.xlabel(r'Autoencoder Loss')
plt.ylabel('Count')
plt.legend(loc='upper right')
# plt.savefig("/data/t3home000/spark/LHCOlympics/plots/NF_bkgAE_autoencoder_loss.png")
plt.show()
